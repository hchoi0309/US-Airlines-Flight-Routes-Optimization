# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import TargetEncoder, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
import xgboost as xgb
from amplpy import AMPL, ampl_notebook
from joblib import load, dump
import sys
sys.path.append("../src")
from utils import cost_prediction

import warnings
warnings.filterwarnings("ignore")
pd.set_option("future.no_silent_downcasting", True) # Prevent silent data type changes during operations for future compatibility

# %% [markdown]
# Instantiate the AMPL object

# %%
ampl = ampl_notebook(
    modules=["highs", "coin"], # solver to be used
    license_uuid="d2b35988-195b-44a4-bca2-fd80a770586f" # license key
)
# Out:
# Licensed to AMPL Community Edition License for <hchoi0309@gmail.com>.

# %%
# %%ampl_eval
# reset;

# %% [markdown]
# Define the model

# %%
# %%ampl_eval
# # Sets
# set ROUTES;
# set AIRPLANE_TYPES;
#
# # Parameters
# param a {ROUTES};          # Base fare price coefficient
# param b {ROUTES};          # Price elasticity coefficient
# param y {ROUTES};          # Yearly effect coefficient
# param c {ROUTES};          # Cost per seat
# param N {ROUTES};          # Predicted daily passengers
# param C {AIRPLANE_TYPES};  # Capacity of each airplane type
# param R {AIRPLANE_TYPES};  # Total airplanes of each type
# param t;                   # Target market share (fraction)
# param year;                # Optimization year
#
# # Variables
# var x {ROUTES} > 0, integer;      # Daily number of seats sold
# var r {ROUTES, AIRPLANE_TYPES} >= 0, integer;  # Number of airplanes assigned per route
#
# # Objective
# maximize Profit:
#     sum {i in ROUTES} (
#         x[i] * (a[i] * exp(-b[i] * x[i] + y[i] * year) - c[i])
#     );
#
# # Constraints
# s.t. MarketShare {i in ROUTES}:
#     x[i] <= N[i];
#
# s.t. MinCapacity {i in ROUTES}:
#     x[i] >= sum {k in AIRPLANE_TYPES} 0.7 * C[k] * r[i, k];
#
# s.t. MaxCapacity {i in ROUTES}:
#     x[i] <= sum {k in AIRPLANE_TYPES} C[k] * r[i, k];
#
# s.t. FleetLimit {k in AIRPLANE_TYPES}:
#     sum {i in ROUTES} r[i, k] <= 3 * R[k];
# Out:
# Warning:
# 	line 18 offset 578
# 	cannot enforce strict bound
# 	context:  var x {ROUTES} >  >>> 0, <<<  integer;      # Daily number of seats sold

# %%
df = pd.read_csv("../data/FINAL_FINAL.csv")
display(df.head())
# Out:
#   airport_1 airport_2  year_coeff  nsmiles           a         b airport_1_2  \
# 0       AUS       IAD   -0.009039     1342  353.079573  0.000288     AUS_IAD
# 1       BNA       IAD    0.013684      587  300.216095  0.000731     BNA_IAD
# 2       BOS       GRR    0.034155      740  391.965759  0.001834     BOS_GRR
# 3       BOS       IND   -0.000761      818  253.127775  0.000074     BOS_IND
# 4       BOS       ORF    0.010823      487  215.865696  0.000175     BOS_ORF
#
#       city_1 state_1 airport_2.1        city_2 state_2  population_1  \
# 0     Austin      TX         IAD    Washington      DC       1905945
# 1  Nashville      TN         IAD    Washington      DC       1177657
# 2     Boston      MA         GRR  Grand Rapids      MI       4328315
# 3     Boston      MA         IND  Indianapolis      IN       4328315
# 4     Boston      MA         ORF       Norfolk      VA       4328315
#
#    density_1    lat_1    lon_1  population_2  density_2    lat_2    lon_2
# 0     1154.1  30.3005 -97.7522       5116378     4235.7  38.9047 -77.0163
# 1      555.4  36.1715 -86.7842       5116378     4235.7  38.9047 -77.0163
# 2     5319.0  42.3188 -71.0852        609023     1708.2  42.9619 -85.6562
# 3     5319.0  42.3188 -71.0852       1729849      941.8  39.7771 -86.1458
# 4     5319.0  42.3188 -71.0852        236973     1717.4  36.8945 -76.2590

# %%
df["year"] = 2019
df["quarter"] = 4
df = df.rename({"nsmiles": "distance"}, axis=1)
df = df.drop(df[df["airport_1_2"] == "LAX_HPN"].index)
display(df.head())
# Out:
#   airport_1 airport_2  year_coeff  distance           a         b airport_1_2  \
# 0       AUS       IAD   -0.009039      1342  353.079573  0.000288     AUS_IAD
# 1       BNA       IAD    0.013684       587  300.216095  0.000731     BNA_IAD
# 2       BOS       GRR    0.034155       740  391.965759  0.001834     BOS_GRR
# 3       BOS       IND   -0.000761       818  253.127775  0.000074     BOS_IND
# 4       BOS       ORF    0.010823       487  215.865696  0.000175     BOS_ORF
#
#       city_1 state_1 airport_2.1  ... population_1 density_1    lat_1  \
# 0     Austin      TX         IAD  ...      1905945    1154.1  30.3005
# 1  Nashville      TN         IAD  ...      1177657     555.4  36.1715
# 2     Boston      MA         GRR  ...      4328315    5319.0  42.3188
# 3     Boston      MA         IND  ...      4328315    5319.0  42.3188
# 4     Boston      MA         ORF  ...      4328315    5319.0  42.3188
#
#      lon_1  population_2  density_2    lat_2    lon_2  year  quarter
# 0 -97.7522       5116378     4235.7  38.9047 -77.0163  2019        4
# 1 -86.7842       5116378     4235.7  38.9047 -77.0163  2019        4
# 2 -71.0852        609023     1708.2  42.9619 -85.6562  2019        4
# 3 -71.0852       1729849      941.8  39.7771 -86.1458  2019        4
# 4 -71.0852        236973     1717.4  36.8945 -76.2590  2019        4
#
# [5 rows x 22 columns]

# %%
df["cost"] = cost_prediction(df, 2019)
display(df.head())
# Out:
#   airport_1 airport_2  year_coeff  distance           a         b airport_1_2  \
# 0       AUS       IAD   -0.009039      1342  353.079573  0.000288     AUS_IAD
# 1       BNA       IAD    0.013684       587  300.216095  0.000731     BNA_IAD
# 2       BOS       GRR    0.034155       740  391.965759  0.001834     BOS_GRR
# 3       BOS       IND   -0.000761       818  253.127775  0.000074     BOS_IND
# 4       BOS       ORF    0.010823       487  215.865696  0.000175     BOS_ORF
#
#       city_1 state_1 airport_2.1  ... density_1    lat_1    lon_1  \
# 0     Austin      TX         IAD  ...    1154.1  30.3005 -97.7522
# 1  Nashville      TN         IAD  ...     555.4  36.1715 -86.7842
# 2     Boston      MA         GRR  ...    5319.0  42.3188 -71.0852
# 3     Boston      MA         IND  ...    5319.0  42.3188 -71.0852
# 4     Boston      MA         ORF  ...    5319.0  42.3188 -71.0852
#
#    population_2  density_2    lat_2    lon_2  year  quarter       cost
# 0       5116378     4235.7  38.9047 -77.0163  2019        4  234.94394
# 1       5116378     4235.7  38.9047 -77.0163  2019        4  102.76609
# 2        609023     1708.2  42.9619 -85.6562  2019        4  129.55180
# 3       1729849      941.8  39.7771 -86.1458  2019        4  143.20726
# 4        236973     1717.4  36.8945 -76.2590  2019        4   85.25909
#
# [5 rows x 23 columns]

# %%
preprocessing_pipeline = load("../models/preprocessing_pipeline.joblib")
feature_names = load("../models/feature_names.joblib")

df_transformed = preprocessing_pipeline.transform(df.drop(["year_coeff", "a", "b", "airport_1_2", "airport_2.1", "cost"], axis=1))
df_transformed = pd.DataFrame(df_transformed, columns=feature_names)
display(df_transformed.head())
# Out:
#    quarter_1  quarter_2  quarter_3  quarter_4    city_1    city_2  airport_1  \
# 0  -0.592028  -0.571486  -0.576259   1.755523 -0.042234 -0.013962  -0.032676
# 1  -0.592028  -0.571486  -0.576259   1.755523 -0.162528 -0.013962  -0.117519
# 2  -0.592028  -0.571486  -0.576259   1.755523 -0.050861 -1.271365   1.496511
# 3  -0.592028  -0.571486  -0.576259   1.755523 -0.050861 -0.751074   1.496511
# 4  -0.592028  -0.571486  -0.576259   1.755523 -0.050861 -1.717950   1.496511
#
#    airport_2   state_1   state_2      year  distance  population_1  density_1  \
# 0  -0.502082 -0.099588 -0.003964  1.204085  0.216246     -0.694892  -0.715648
# 1  -0.502082 -1.044005 -0.003964  1.204085 -0.857693     -0.826930  -0.916193
# 2  -0.855942 -0.056457  0.950370  1.204085 -0.640060     -0.255718   0.679458
# 3  -0.507130 -0.056457 -1.230771  1.204085 -0.529110     -0.255718   0.679458
# 4  -0.952062 -0.056457 -2.422257  1.204085 -0.999937     -0.255718   0.679458
#
#    population_2  density_2     lat_1     lon_1     lat_2     lon_2
# 0     -0.172653   0.043854 -1.699120 -0.522722  0.129862  0.839686
# 1     -0.172653   0.043854 -0.464798  0.186303  0.129862  0.839686
# 2     -0.904045  -0.688692  0.827613  1.201164  0.989342  0.384514
# 3     -0.722173  -0.910818  0.827613  1.201164  0.314672  0.358721
# 4     -0.964416  -0.686026  0.827613  1.201164 -0.295980  0.879582

# %%
demand_model = load("../models/demand_prediction_model.joblib")

df["predicted_passengers"] = np.abs(demand_model.predict(df_transformed))
df = df[["year_coeff", "a", "b", "airport_1_2", "cost", "predicted_passengers"]]
display(df.head())
# Out:
#    year_coeff           a         b airport_1_2       cost  \
# 0   -0.009039  353.079573  0.000288     AUS_IAD  234.94394
# 1    0.013684  300.216095  0.000731     BNA_IAD  102.76609
# 2    0.034155  391.965759  0.001834     BOS_GRR  129.55180
# 3   -0.000761  253.127775  0.000074     BOS_IND  143.20726
# 4    0.010823  215.865696  0.000175     BOS_ORF   85.25909
#
#    predicted_passengers
# 0            323.784943
# 1            220.126175
# 2            151.138489
# 3            512.026611
# 4            243.720016

# %%
fleet_df = pd.read_csv("../data/allegiant_fleet.csv")
display(fleet_df)
# Out:
#         Aircraft Type  Number of Aircraft  Seats
# 0     Airbus A319-100                  34    156
# 1   Airbus A320-200 A                  14    177
# 2   Airbus A320-200 B                  78    186
# 3  Boeing 737 MAX 200                   2    190

# %% [markdown]
# Define the problem

# %%
# 2. Load the data into AMPL
# Assuming df and fleet_df are your dataframes containing the necessary data
ampl.set["ROUTES"] = df["airport_1_2"].unique()
ampl.set["AIRPLANE_TYPES"] = fleet_df["Aircraft Type"]

# Load parameters
ampl.param["a"] = {row["airport_1_2"]: row["a"] for _, row in df.drop_duplicates("airport_1_2").iterrows()}
ampl.param["b"] = {row["airport_1_2"]: row["b"] for _, row in df.drop_duplicates("airport_1_2").iterrows()}
ampl.param["y"] = {row["airport_1_2"]: row["year_coeff"] for _, row in df.drop_duplicates("airport_1_2").iterrows()}
ampl.param["c"] = {row["airport_1_2"]: row["cost"] for _, row in df.drop_duplicates("airport_1_2").iterrows()}
ampl.param["N"] = {row["airport_1_2"]: row["predicted_passengers"] for _, row in df.drop_duplicates("airport_1_2").iterrows()}

ampl.param["C"] = {row["Aircraft Type"]: row["Seats"] for _, row in fleet_df.iterrows()}
ampl.param["R"] = {row["Aircraft Type"]: row["Number of Aircraft"] for _, row in fleet_df.iterrows()}

ampl.param["t"] = 0.8  # Target market share (80%)
ampl.param["year"] = 2024  # Current year

# 3. Set solver and solve
ampl.option["solver"] = "ipopt"  # Use ipopt for nonlinear problems
ampl.solve()

# 4. Retrieve and display results
try:
    # Get results
    x_values = ampl.getVariable("x").getValues().toPandas()
    r_values = ampl.getVariable("r").getValues().toPandas()
    profit = ampl.getObjective("Profit").value()

    print("Optimal seat allocation:")
    print(x_values)
    print("\nAircraft assignment:")
    print(r_values)
    print(f"\nTotal profit: ${profit:,.2f}")

except Exception as e:
    print("Error solving the model:")
    print(e)
    
    # Debug information
    print("\nParameter values:")
    print("Routes:", list(ampl.set["ROUTES"]))
    print("N values:", ampl.param["N"].getValues().toPandas())
    print("a values:", ampl.param["a"].getValues().toPandas())
# Out:
# Ipopt 3.12.13:
# ==> Warning: Treating 134 binary and 817 integer variables as continous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:     2661
# Number of nonzeros in Lagrangian Hessian.............:      140
#
# Total number of variables............................:      951
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      811
#                      variables with only upper bounds:      140
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:      388
#         inequality constraints with only lower bounds:      192
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      196
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -8.3512502e+87 4.96e+00 7.36e+281  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -4.8855049e+215 4.96e+00 7.36e+281  -1.0 8.35e+79    -  1.19e-82 4.29e-78f  1
#    2 -4.8856402e+215 4.96e+00 7.36e+281  -1.0 3.02e+82    -  1.10e-80 1.19e-82f  1
#    3 -4.8981629e+215 4.96e+00 7.36e+281  -1.0 3.26e+78    -  5.65e-77 1.10e-80f  1
#    4 -6.8594698e+216 4.96e+00 7.36e+281  -1.0 6.40e+72    -  2.97e-71 5.60e-77f  1
#    5 -3.3445474e+222 4.96e+00 7.36e+281  -1.0 1.22e+65    -  2.81e-64 2.94e-71f  1
#    6 -3.7277066e+227 4.96e+00 7.36e+281  -1.0 1.09e+58    -  1.04e-58 3.27e-66f  1
#    7 -3.7650673e+229 4.96e+00 7.36e+281  -1.0 1.09e+54    -  7.22e-55 3.27e-64f  1
#    8 -3.7468019e+231 4.96e+00 7.36e+281  -1.0 1.11e+50    -  7.12e-51 3.26e-62f  1
# In iteration 8, 1 Slack too small, adjusting variable bound
#    9 -2.4113248e+233 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 9, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -6.0794841e+236 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 10, 1 Slack too small, adjusting variable bound
#   11 -6.0794841e+236 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   12 -6.0794843e+236 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   13 -6.0795048e+236 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 13, 1 Slack too small, adjusting variable bound
#   14 -6.0818787e+236 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 14, 1 Slack too small, adjusting variable bound
#   15 -1.2158951e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 15, 1 Slack too small, adjusting variable bound
#   16 -1.2158951e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   17 -1.2158952e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   18 -1.2158972e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 18, 1 Slack too small, adjusting variable bound
#   19 -1.2161346e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 19, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 -1.8238419e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 20, 1 Slack too small, adjusting variable bound
#   21 -1.8238419e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   22 -1.8238419e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   23 -1.8238439e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 23, 1 Slack too small, adjusting variable bound
#   24 -1.8240813e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 24, 1 Slack too small, adjusting variable bound
#   25 -2.4317886e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 25, 1 Slack too small, adjusting variable bound
#   26 -2.4317886e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   27 -2.4317886e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   28 -2.4317907e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 28, 1 Slack too small, adjusting variable bound
#   29 -2.4320281e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 29, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30 -3.0397353e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 30, 1 Slack too small, adjusting variable bound
#   31 -3.0397353e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   32 -3.0397354e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   33 -3.0397374e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 33, 1 Slack too small, adjusting variable bound
#   34 -3.0399748e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 34, 1 Slack too small, adjusting variable bound
#   35 -3.6476821e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 35, 1 Slack too small, adjusting variable bound
#   36 -3.6476821e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   37 -3.6476821e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   38 -3.6476841e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 38, 1 Slack too small, adjusting variable bound
#   39 -3.6479215e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 39, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40 -4.2556288e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 40, 1 Slack too small, adjusting variable bound
#   41 -4.2556288e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   42 -4.2556288e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   43 -4.2556309e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 43, 1 Slack too small, adjusting variable bound
#   44 -4.2558683e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 44, 1 Slack too small, adjusting variable bound
#   45 -4.8635755e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 45, 1 Slack too small, adjusting variable bound
#   46 -4.8635755e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   47 -4.8635756e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   48 -4.8635776e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 48, 1 Slack too small, adjusting variable bound
#   49 -4.8638150e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 49, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -5.4715223e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 50, 1 Slack too small, adjusting variable bound
#   51 -5.4715223e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   52 -5.4715223e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   53 -5.4715243e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 53, 1 Slack too small, adjusting variable bound
#   54 -5.4717617e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 54, 1 Slack too small, adjusting variable bound
#   55 -6.0794690e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 55, 1 Slack too small, adjusting variable bound
#   56 -6.0794690e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   57 -6.0794690e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   58 -6.0794711e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 58, 1 Slack too small, adjusting variable bound
#   59 -6.0797085e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 59, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -6.6874157e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 60, 1 Slack too small, adjusting variable bound
#   61 -6.6874157e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   62 -6.6874158e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   63 -6.6874178e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 63, 1 Slack too small, adjusting variable bound
#   64 -6.6876552e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 64, 1 Slack too small, adjusting variable bound
#   65 -7.2953625e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 65, 1 Slack too small, adjusting variable bound
#   66 -7.2953625e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   67 -7.2953625e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   68 -7.2953645e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 68, 1 Slack too small, adjusting variable bound
#   69 -7.2956019e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 69, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70 -7.9033092e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 70, 1 Slack too small, adjusting variable bound
#   71 -7.9033092e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   72 -7.9033092e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   73 -7.9033113e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 73, 1 Slack too small, adjusting variable bound
#   74 -7.9035487e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 74, 1 Slack too small, adjusting variable bound
#   75 -8.5112559e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 75, 1 Slack too small, adjusting variable bound
#   76 -8.5112559e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   77 -8.5112560e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   78 -8.5112580e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 78, 1 Slack too small, adjusting variable bound
#   79 -8.5114954e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 79, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80 -9.1192027e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 80, 1 Slack too small, adjusting variable bound
#   81 -9.1192027e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   82 -9.1192027e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   83 -9.1192047e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 83, 1 Slack too small, adjusting variable bound
#   84 -9.1194421e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 84, 1 Slack too small, adjusting variable bound
#   85 -9.7271494e+237 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 85, 1 Slack too small, adjusting variable bound
#   86 -9.7271494e+237 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   87 -9.7271494e+237 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   88 -9.7271515e+237 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 88, 1 Slack too small, adjusting variable bound
#   89 -9.7273889e+237 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 89, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90 -1.0335096e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 90, 1 Slack too small, adjusting variable bound
#   91 -1.0335096e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   92 -1.0335096e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.17e-55 1.80e-64f  1
#   93 -1.0335098e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 93, 1 Slack too small, adjusting variable bound
#   94 -1.0335336e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 94, 1 Slack too small, adjusting variable bound
#   95 -1.0943043e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 95, 1 Slack too small, adjusting variable bound
#   96 -1.0943043e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#   97 -1.0943043e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#   98 -1.0943045e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 98, 1 Slack too small, adjusting variable bound
#   99 -1.0943282e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 99, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100 -1.1550990e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 100, 1 Slack too small, adjusting variable bound
#  101 -1.1550990e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  102 -1.1550990e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  103 -1.1550992e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 103, 1 Slack too small, adjusting variable bound
#  104 -1.1551229e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 104, 1 Slack too small, adjusting variable bound
#  105 -1.2158936e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 105, 1 Slack too small, adjusting variable bound
#  106 -1.2158936e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  107 -1.2158936e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  108 -1.2158938e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 108, 1 Slack too small, adjusting variable bound
#  109 -1.2159176e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 109, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110 -1.2766883e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 110, 1 Slack too small, adjusting variable bound
#  111 -1.2766883e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  112 -1.2766883e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  113 -1.2766885e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 113, 1 Slack too small, adjusting variable bound
#  114 -1.2767123e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 114, 1 Slack too small, adjusting variable bound
#  115 -1.3374830e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 115, 1 Slack too small, adjusting variable bound
#  116 -1.3374830e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  117 -1.3374830e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  118 -1.3374832e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 118, 1 Slack too small, adjusting variable bound
#  119 -1.3375069e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 119, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120 -1.3982777e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 120, 1 Slack too small, adjusting variable bound
#  121 -1.3982777e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  122 -1.3982777e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  123 -1.3982779e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 123, 1 Slack too small, adjusting variable bound
#  124 -1.3983016e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 124, 1 Slack too small, adjusting variable bound
#  125 -1.4590723e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 125, 1 Slack too small, adjusting variable bound
#  126 -1.4590723e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  127 -1.4590723e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  128 -1.4590725e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 128, 1 Slack too small, adjusting variable bound
#  129 -1.4590963e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 129, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130 -1.5198670e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 130, 1 Slack too small, adjusting variable bound
#  131 -1.5198670e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  132 -1.5198670e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  133 -1.5198672e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 133, 1 Slack too small, adjusting variable bound
#  134 -1.5198909e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 134, 1 Slack too small, adjusting variable bound
#  135 -1.5806617e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 135, 1 Slack too small, adjusting variable bound
#  136 -1.5806617e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  137 -1.5806617e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  138 -1.5806619e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 138, 1 Slack too small, adjusting variable bound
#  139 -1.5806856e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 139, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140 -1.6414563e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 140, 1 Slack too small, adjusting variable bound
#  141 -1.6414563e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  142 -1.6414563e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  143 -1.6414566e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 143, 1 Slack too small, adjusting variable bound
#  144 -1.6414803e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 144, 1 Slack too small, adjusting variable bound
#  145 -1.7022510e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 145, 1 Slack too small, adjusting variable bound
#  146 -1.7022510e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  147 -1.7022510e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  148 -1.7022512e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 148, 1 Slack too small, adjusting variable bound
#  149 -1.7022750e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 149, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150 -1.7630457e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 150, 1 Slack too small, adjusting variable bound
#  151 -1.7630457e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  152 -1.7630457e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  153 -1.7630459e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 153, 1 Slack too small, adjusting variable bound
#  154 -1.7630696e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 154, 1 Slack too small, adjusting variable bound
#  155 -1.8238404e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 155, 1 Slack too small, adjusting variable bound
#  156 -1.8238404e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  157 -1.8238404e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  158 -1.8238406e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 158, 1 Slack too small, adjusting variable bound
#  159 -1.8238643e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 159, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160 -1.8846350e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 160, 1 Slack too small, adjusting variable bound
#  161 -1.8846350e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  162 -1.8846350e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  163 -1.8846352e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 163, 1 Slack too small, adjusting variable bound
#  164 -1.8846590e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 164, 1 Slack too small, adjusting variable bound
#  165 -1.9454297e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 165, 1 Slack too small, adjusting variable bound
#  166 -1.9454297e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  167 -1.9454297e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  168 -1.9454299e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 168, 1 Slack too small, adjusting variable bound
#  169 -1.9454537e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 169, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170 -2.0062244e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 170, 1 Slack too small, adjusting variable bound
#  171 -2.0062244e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  172 -2.0062244e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  173 -2.0062246e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 173, 1 Slack too small, adjusting variable bound
#  174 -2.0062483e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 174, 1 Slack too small, adjusting variable bound
#  175 -2.0670191e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 175, 1 Slack too small, adjusting variable bound
#  176 -2.0670191e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  177 -2.0670191e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  178 -2.0670193e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 178, 1 Slack too small, adjusting variable bound
#  179 -2.0670430e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 179, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180 -2.1278137e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 180, 1 Slack too small, adjusting variable bound
#  181 -2.1278137e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  182 -2.1278137e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  183 -2.1278139e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 183, 1 Slack too small, adjusting variable bound
#  184 -2.1278377e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 184, 1 Slack too small, adjusting variable bound
#  185 -2.1886084e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 185, 1 Slack too small, adjusting variable bound
#  186 -2.1886084e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  187 -2.1886084e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  188 -2.1886086e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 188, 1 Slack too small, adjusting variable bound
#  189 -2.1886324e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 189, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190 -2.2494031e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 190, 1 Slack too small, adjusting variable bound
#  191 -2.2494031e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  192 -2.2494031e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  193 -2.2494033e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 193, 1 Slack too small, adjusting variable bound
#  194 -2.2494270e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 194, 1 Slack too small, adjusting variable bound
#  195 -2.3101978e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 195, 1 Slack too small, adjusting variable bound
#  196 -2.3101978e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  197 -2.3101978e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  198 -2.3101980e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 198, 1 Slack too small, adjusting variable bound
#  199 -2.3102217e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 199, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200 -2.3709924e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 200, 1 Slack too small, adjusting variable bound
#  201 -2.3709924e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  202 -2.3709924e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  203 -2.3709926e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 203, 1 Slack too small, adjusting variable bound
#  204 -2.3710164e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 204, 1 Slack too small, adjusting variable bound
#  205 -2.4317871e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 205, 1 Slack too small, adjusting variable bound
#  206 -2.4317871e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  207 -2.4317871e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  208 -2.4317873e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 208, 1 Slack too small, adjusting variable bound
#  209 -2.4318110e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 209, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210 -2.4925818e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 210, 1 Slack too small, adjusting variable bound
#  211 -2.4925818e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  212 -2.4925818e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  213 -2.4925820e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 213, 1 Slack too small, adjusting variable bound
#  214 -2.4926057e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 214, 1 Slack too small, adjusting variable bound
#  215 -2.5533764e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.91e-40 5.34e-57f  1
# In iteration 215, 1 Slack too small, adjusting variable bound
#  216 -2.5533764e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.91e-60 5.34e-77f  1
#  217 -2.5533764e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  218 -2.5533767e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 218, 1 Slack too small, adjusting variable bound
#  219 -2.5534004e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 219, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220 -2.6141711e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 220, 1 Slack too small, adjusting variable bound
#  221 -2.6141711e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  222 -2.6141711e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  223 -2.6141713e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 223, 1 Slack too small, adjusting variable bound
#  224 -2.6141951e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 224, 1 Slack too small, adjusting variable bound
#  225 -2.6749658e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 225, 1 Slack too small, adjusting variable bound
#  226 -2.6749658e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  227 -2.6749658e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  228 -2.6749660e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 228, 1 Slack too small, adjusting variable bound
#  229 -2.6749897e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 229, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230 -2.7357605e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 230, 1 Slack too small, adjusting variable bound
#  231 -2.7357605e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  232 -2.7357605e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  233 -2.7357607e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 233, 1 Slack too small, adjusting variable bound
#  234 -2.7357844e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 234, 1 Slack too small, adjusting variable bound
#  235 -2.7965551e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 235, 1 Slack too small, adjusting variable bound
#  236 -2.7965551e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  237 -2.7965551e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  238 -2.7965553e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 238, 1 Slack too small, adjusting variable bound
#  239 -2.7965791e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 239, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240 -2.8573498e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 240, 1 Slack too small, adjusting variable bound
#  241 -2.8573498e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  242 -2.8573498e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  243 -2.8573500e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 243, 1 Slack too small, adjusting variable bound
#  244 -2.8573738e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 244, 1 Slack too small, adjusting variable bound
#  245 -2.9181445e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 245, 1 Slack too small, adjusting variable bound
#  246 -2.9181445e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  247 -2.9181445e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  248 -2.9181447e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 248, 1 Slack too small, adjusting variable bound
#  249 -2.9181684e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 249, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250 -2.9789392e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 250, 1 Slack too small, adjusting variable bound
#  251 -2.9789392e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  252 -2.9789392e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  253 -2.9789394e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 253, 1 Slack too small, adjusting variable bound
#  254 -2.9789631e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 254, 1 Slack too small, adjusting variable bound
#  255 -3.0397338e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 255, 1 Slack too small, adjusting variable bound
#  256 -3.0397338e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  257 -3.0397338e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  258 -3.0397340e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 258, 1 Slack too small, adjusting variable bound
#  259 -3.0397578e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 259, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260 -3.1005285e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 260, 1 Slack too small, adjusting variable bound
#  261 -3.1005285e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  262 -3.1005285e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  263 -3.1005287e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 263, 1 Slack too small, adjusting variable bound
#  264 -3.1005525e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 264, 1 Slack too small, adjusting variable bound
#  265 -3.1613232e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 265, 1 Slack too small, adjusting variable bound
#  266 -3.1613232e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  267 -3.1613232e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  268 -3.1613234e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 268, 1 Slack too small, adjusting variable bound
#  269 -3.1613471e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 269, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270 -3.2221179e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 270, 1 Slack too small, adjusting variable bound
#  271 -3.2221179e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  272 -3.2221179e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  273 -3.2221181e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 273, 1 Slack too small, adjusting variable bound
#  274 -3.2221418e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 274, 1 Slack too small, adjusting variable bound
#  275 -3.2829125e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 275, 1 Slack too small, adjusting variable bound
#  276 -3.2829125e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  277 -3.2829125e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  278 -3.2829127e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 278, 1 Slack too small, adjusting variable bound
#  279 -3.2829365e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 279, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280 -3.3437072e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 280, 1 Slack too small, adjusting variable bound
#  281 -3.3437072e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  282 -3.3437072e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  283 -3.3437074e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 283, 1 Slack too small, adjusting variable bound
#  284 -3.3437311e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 284, 1 Slack too small, adjusting variable bound
#  285 -3.4045019e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 285, 1 Slack too small, adjusting variable bound
#  286 -3.4045019e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  287 -3.4045019e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  288 -3.4045021e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 288, 1 Slack too small, adjusting variable bound
#  289 -3.4045258e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 289, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290 -3.4652965e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 290, 1 Slack too small, adjusting variable bound
#  291 -3.4652965e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  292 -3.4652965e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  293 -3.4652968e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 293, 1 Slack too small, adjusting variable bound
#  294 -3.4653205e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 294, 1 Slack too small, adjusting variable bound
#  295 -3.5260912e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 295, 1 Slack too small, adjusting variable bound
#  296 -3.5260912e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  297 -3.5260912e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  298 -3.5260914e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 298, 1 Slack too small, adjusting variable bound
#  299 -3.5261152e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 299, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300 -3.5868859e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 300, 1 Slack too small, adjusting variable bound
#  301 -3.5868859e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  302 -3.5868859e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  303 -3.5868861e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 303, 1 Slack too small, adjusting variable bound
#  304 -3.5869098e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 304, 1 Slack too small, adjusting variable bound
#  305 -3.6476806e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 305, 1 Slack too small, adjusting variable bound
#  306 -3.6476806e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  307 -3.6476806e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  308 -3.6476808e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 308, 1 Slack too small, adjusting variable bound
#  309 -3.6477045e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 309, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310 -3.7084752e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 310, 1 Slack too small, adjusting variable bound
#  311 -3.7084752e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  312 -3.7084752e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  313 -3.7084754e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 313, 1 Slack too small, adjusting variable bound
#  314 -3.7084992e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 314, 1 Slack too small, adjusting variable bound
#  315 -3.7692699e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 315, 1 Slack too small, adjusting variable bound
#  316 -3.7692699e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  317 -3.7692699e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  318 -3.7692701e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 318, 1 Slack too small, adjusting variable bound
#  319 -3.7692939e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 319, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320 -3.8300646e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 320, 1 Slack too small, adjusting variable bound
#  321 -3.8300646e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  322 -3.8300646e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  323 -3.8300648e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 323, 1 Slack too small, adjusting variable bound
#  324 -3.8300885e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 324, 1 Slack too small, adjusting variable bound
#  325 -3.8908593e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 325, 1 Slack too small, adjusting variable bound
#  326 -3.8908593e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  327 -3.8908593e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  328 -3.8908595e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 328, 1 Slack too small, adjusting variable bound
#  329 -3.8908832e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 329, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330 -3.9516539e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 330, 1 Slack too small, adjusting variable bound
#  331 -3.9516539e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  332 -3.9516539e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  333 -3.9516541e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 333, 1 Slack too small, adjusting variable bound
#  334 -3.9516779e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 334, 1 Slack too small, adjusting variable bound
#  335 -4.0124486e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 335, 1 Slack too small, adjusting variable bound
#  336 -4.0124486e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  337 -4.0124486e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  338 -4.0124488e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 338, 1 Slack too small, adjusting variable bound
#  339 -4.0124726e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.92e-47 2.09e-60f  1
# In iteration 339, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340 -4.0732433e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 340, 1 Slack too small, adjusting variable bound
#  341 -4.0732433e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  342 -4.0732433e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  343 -4.0732435e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 343, 1 Slack too small, adjusting variable bound
#  344 -4.0732672e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.93e-47 2.09e-60f  1
# In iteration 344, 1 Slack too small, adjusting variable bound
#  345 -4.1340380e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 345, 1 Slack too small, adjusting variable bound
#  346 -4.1340380e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  347 -4.1340380e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  348 -4.1340382e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 348, 1 Slack too small, adjusting variable bound
#  349 -4.1340619e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.93e-47 2.09e-60f  1
# In iteration 349, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350 -4.1948326e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 350, 1 Slack too small, adjusting variable bound
#  351 -4.1948326e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  352 -4.1948326e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  353 -4.1948328e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 353, 1 Slack too small, adjusting variable bound
#  354 -4.1948566e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.93e-47 2.09e-60f  1
# In iteration 354, 1 Slack too small, adjusting variable bound
#  355 -4.2556273e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 355, 1 Slack too small, adjusting variable bound
#  356 -4.2556273e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  357 -4.2556273e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  358 -4.2556275e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 358, 1 Slack too small, adjusting variable bound
#  359 -4.2556512e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.93e-47 2.09e-60f  1
# In iteration 359, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360 -4.3164220e+238 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 360, 1 Slack too small, adjusting variable bound
#  361 -4.3164220e+238 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
#  362 -4.3164220e+238 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.18e-55 1.80e-64f  1
#  363 -4.3164222e+238 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.17e-51 1.80e-62f  1
# In iteration 363, 1 Slack too small, adjusting variable bound
#  364 -4.3164459e+238 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.93e-47 2.09e-60f  1
# In iteration 364, 1 Slack too small, adjusting variable bound
# ...
# In iteration 2895, 1 Slack too small, adjusting variable bound
# 2896 -3.5139321e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2897 -3.5139321e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2898 -3.5139322e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2898, 1 Slack too small, adjusting variable bound
# 2899 -3.5139345e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2899, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2900 -3.5200116e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2900, 1 Slack too small, adjusting variable bound
# 2901 -3.5200116e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2902 -3.5200116e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2903 -3.5200116e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2903, 1 Slack too small, adjusting variable bound
# 2904 -3.5200140e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2904, 1 Slack too small, adjusting variable bound
# 2905 -3.5260911e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2905, 1 Slack too small, adjusting variable bound
# 2906 -3.5260911e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2907 -3.5260911e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2908 -3.5260911e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2908, 1 Slack too small, adjusting variable bound
# 2909 -3.5260935e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2909, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2910 -3.5321705e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2910, 1 Slack too small, adjusting variable bound
# 2911 -3.5321705e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2912 -3.5321705e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2913 -3.5321706e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2913, 1 Slack too small, adjusting variable bound
# 2914 -3.5321729e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2914, 1 Slack too small, adjusting variable bound
# 2915 -3.5382500e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2915, 1 Slack too small, adjusting variable bound
# 2916 -3.5382500e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2917 -3.5382500e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2918 -3.5382500e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2918, 1 Slack too small, adjusting variable bound
# 2919 -3.5382524e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2919, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2920 -3.5443295e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2920, 1 Slack too small, adjusting variable bound
# 2921 -3.5443295e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2922 -3.5443295e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2923 -3.5443295e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2923, 1 Slack too small, adjusting variable bound
# 2924 -3.5443319e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2924, 1 Slack too small, adjusting variable bound
# 2925 -3.5504089e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2925, 1 Slack too small, adjusting variable bound
# 2926 -3.5504089e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2927 -3.5504089e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2928 -3.5504090e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2928, 1 Slack too small, adjusting variable bound
# 2929 -3.5504113e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2929, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2930 -3.5564884e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2930, 1 Slack too small, adjusting variable bound
# 2931 -3.5564884e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2932 -3.5564884e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2933 -3.5564884e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2933, 1 Slack too small, adjusting variable bound
# 2934 -3.5564908e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2934, 1 Slack too small, adjusting variable bound
# 2935 -3.5625679e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2935, 1 Slack too small, adjusting variable bound
# 2936 -3.5625679e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2937 -3.5625679e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2938 -3.5625679e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2938, 1 Slack too small, adjusting variable bound
# 2939 -3.5625703e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2939, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2940 -3.5686473e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2940, 1 Slack too small, adjusting variable bound
# 2941 -3.5686473e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2942 -3.5686473e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2943 -3.5686474e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2943, 1 Slack too small, adjusting variable bound
# 2944 -3.5686497e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2944, 1 Slack too small, adjusting variable bound
# 2945 -3.5747268e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2945, 1 Slack too small, adjusting variable bound
# 2946 -3.5747268e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2947 -3.5747268e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2948 -3.5747268e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2948, 1 Slack too small, adjusting variable bound
# 2949 -3.5747292e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2949, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2950 -3.5808063e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2950, 1 Slack too small, adjusting variable bound
# 2951 -3.5808063e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2952 -3.5808063e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2953 -3.5808063e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2953, 1 Slack too small, adjusting variable bound
# 2954 -3.5808087e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2954, 1 Slack too small, adjusting variable bound
# 2955 -3.5868857e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2955, 1 Slack too small, adjusting variable bound
# 2956 -3.5868857e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2957 -3.5868857e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2958 -3.5868858e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2958, 1 Slack too small, adjusting variable bound
# 2959 -3.5868881e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2959, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2960 -3.5929652e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2960, 1 Slack too small, adjusting variable bound
# 2961 -3.5929652e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2962 -3.5929652e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2963 -3.5929652e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2963, 1 Slack too small, adjusting variable bound
# 2964 -3.5929676e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2964, 1 Slack too small, adjusting variable bound
# 2965 -3.5990447e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2965, 1 Slack too small, adjusting variable bound
# 2966 -3.5990447e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2967 -3.5990447e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2968 -3.5990447e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2968, 1 Slack too small, adjusting variable bound
# 2969 -3.5990471e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2969, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2970 -3.6051241e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2970, 1 Slack too small, adjusting variable bound
# 2971 -3.6051241e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2972 -3.6051241e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2973 -3.6051242e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2973, 1 Slack too small, adjusting variable bound
# 2974 -3.6051265e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2974, 1 Slack too small, adjusting variable bound
# 2975 -3.6112036e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2975, 1 Slack too small, adjusting variable bound
# 2976 -3.6112036e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2977 -3.6112036e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2978 -3.6112036e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2978, 1 Slack too small, adjusting variable bound
# 2979 -3.6112060e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2979, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2980 -3.6172831e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2980, 1 Slack too small, adjusting variable bound
# 2981 -3.6172831e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2982 -3.6172831e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2983 -3.6172831e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2983, 1 Slack too small, adjusting variable bound
# 2984 -3.6172855e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2984, 1 Slack too small, adjusting variable bound
# 2985 -3.6233625e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2985, 1 Slack too small, adjusting variable bound
# 2986 -3.6233625e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2987 -3.6233625e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2988 -3.6233626e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2988, 1 Slack too small, adjusting variable bound
# 2989 -3.6233649e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2989, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2990 -3.6294420e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2990, 1 Slack too small, adjusting variable bound
# 2991 -3.6294420e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2992 -3.6294420e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2993 -3.6294420e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2993, 1 Slack too small, adjusting variable bound
# 2994 -3.6294444e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2994, 1 Slack too small, adjusting variable bound
# 2995 -3.6355215e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
# In iteration 2995, 1 Slack too small, adjusting variable bound
# 2996 -3.6355215e+239 4.96e+00 7.36e+281  -1.0 4.12e+59    -  1.92e-60 5.34e-77f  1
# 2997 -3.6355215e+239 4.96e+00 7.36e+281  -1.0 3.62e+54    -  2.19e-55 1.80e-64f  1
# 2998 -3.6355215e+239 4.96e+00 7.36e+281  -1.0 3.63e+50    -  2.18e-51 1.80e-62f  1
# In iteration 2998, 1 Slack too small, adjusting variable bound
# 2999 -3.6355239e+239 4.96e+00 7.36e+281  -1.0 2.70e+46    -  2.94e-47 2.09e-60f  1
# In iteration 2999, 1 Slack too small, adjusting variable bound
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3000 -3.6416009e+239 4.96e+00 7.36e+281  -1.0 4.12e+39    -  1.92e-40 5.34e-57f  1
#
# Number of Iterations....: 3000
#
#                                    (scaled)                 (unscaled)
# Objective...............: -3.6416009471539339e+231  -3.6416009471539339e+239
# Dual infeasibility......:  7.3564245513552414e+281   7.3564245513552416e+289
# Constraint violation....:   3.7315852892020862e+00    4.9630084346387751e+00
# Complementarity.........:   7.6428954139463649e+03    7.6428954139463647e+11
# Overall NLP error.......:  4.1244985986406657e+281   7.3564245513552416e+289
#
#
# Number of objective function evaluations             = 3001
# Number of objective gradient evaluations             = 3001
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 3001
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 3001
# Number of Lagrangian Hessian evaluations             = 3000
# Total CPU secs in IPOPT (w/o function evaluations)   =     24.199
# Total CPU secs in NLP function evaluations           =      0.404
#
# EXIT: Maximum Number of Iterations Exceeded.
#
# Ipopt 3.12.13: Maximum Number of Iterations Exceeded.
#
# suffix ipopt_zU_out OUT;
# suffix ipopt_zL_out OUT;
# Optimal seat allocation:
#                 x.val
# AUS_BOS -2.265894e-02
# AUS_BUR  0.000000e+00
# AUS_BWI -1.790112e-07
# AUS_CLE  7.333181e-51
# AUS_CMH -8.145879e-33
# ...               ...
# PHX_TUL  9.996320e-03
# SNA_GEG -3.788845e-07
# SNA_MFR -5.551264e-07
# SRQ_IAD  0.000000e+00
# VPS_BWI  0.000000e+00
#
# [202 rows x 1 columns]
#
# Aircraft assignment:
#                                r.val
# index0  index1
# AUS_BOS Airbus A319-100     0.010292
#         Airbus A320-200 A   0.010219
#         Airbus A320-200 B   0.010395
#         Boeing 737 MAX 200  0.008999
# AUS_BUR Airbus A319-100     0.000000
# ...                              ...
# SRQ_IAD Boeing 737 MAX 200  0.000000
# VPS_BWI Airbus A319-100     0.000000
#         Airbus A320-200 A   0.000000
#         Airbus A320-200 B   0.000000
#         Boeing 737 MAX 200  0.000000
#
# [808 rows x 1 columns]
#
# Total profit: $364,160,094,715,393,393,062,380,397,470,103,594,721,480,644,628,638,451,713,774,272,574,678,335,653,476,897,123,377,493,454,976,570,897,243,662,395,732,783,841,572,401,177,216,609,246,174,593,004,614,859,837,795,175,538,299,619,932,253,934,562,676,953,936,647,391,250,680,696,662,769,071,234,099,617,870,948,847,321,088.00

# %%
ampl.set["ROUTES"] = df["airport_1_2"].drop_duplicates()
ampl.param["a"] = df.set_index("airport_1_2")["a"]
ampl.param["b"] = df.set_index("airport_1_2")["b"]
ampl.param["y"] = df.set_index("airport_1_2")["year_coeff"]
ampl.param["c"] = df.set_index("airport_1_2")["cost"]
ampl.param["N"] = df.set_index("airport_1_2")["predicted_passengers"]

ampl.set["AIRPLANE_TYPES"] = fleet_df["Aircraft Type"]
ampl.param["C"] = fleet_df.groupby("Aircraft Type")["Seats"].first()
ampl.param["R"] = fleet_df.groupby("Aircraft Type")["Number of Aircraft"].first()

ampl.param["t"] = 0.8
ampl.param["year"] = 2019

# %%
# %%ampl_eval
# option solver ipopt
# solve;

# %%
# Retrieve results
x = ampl.getVariable("x").getValues().toPandas()
r = ampl.getVariable("r").getValues().toPandas()
profit = ampl.getObjective("Profit").value()

# Display results
print("Optimal Seat Sales (x):")
print(x)

print("\nAirplane Assignments (r):")
print(r)

print(f"\nTotal Profit: {profit}")
# Out:
# Optimal Seat Sales (x):
#          x.val
# AUS_BOS      0
# AUS_BUR      0
# AUS_BWI      0
# AUS_CLE      0
# AUS_CMH      0
# ...        ...
# PHX_TUL      0
# SNA_GEG      0
# SNA_MFR      0
# SRQ_IAD      0
# VPS_BWI      0
#
# [202 rows x 1 columns]
#
# Airplane Assignments (r):
#                             r.val
# index0  index1
# AUS_BOS Airbus A319-100         0
#         Airbus A320-200 A       0
#         Airbus A320-200 B       0
#         Boeing 737 MAX 200      0
# AUS_BUR Airbus A319-100         0
# ...                           ...
# SRQ_IAD Boeing 737 MAX 200      0
# VPS_BWI Airbus A319-100         0
#         Airbus A320-200 A       0
#         Airbus A320-200 B       0
#         Boeing 737 MAX 200      0
#
# [808 rows x 1 columns]
#
# Total Profit: 0.0

# %%
# Debugging: Print parameter values for a specific route
print("Debugging route parameters:")
for route in ["AUS_IAD", "BOS_ORF"]:  # Example routes
    print(f"Route: {route}")
    print(f"a: {df.loc[df['airport_1_2'] == route, 'a'].values[0]}")
    print(f"b: {df.loc[df['airport_1_2'] == route, 'b'].values[0]}")
    print(f"y: {df.loc[df['airport_1_2'] == route, 'year_coeff'].values[0]}")
    print(f"c: {df.loc[df['airport_1_2'] == route, 'cost'].values[0]}")
    print(f"N: {df.loc[df['airport_1_2'] == route, 'predicted_passengers'].values[0]}")
    print()
# Out:
# Debugging route parameters:
# Route: AUS_IAD
# a: 353.0795727
# b: 0.000287919
# y: -0.009039018
# c: 234.94394
# N: 323.7849426269531
#
# Route: BOS_ORF
# a: 215.8656962
# b: 0.000174883
# y: 0.010823479
# c: 85.25909
# N: 243.7200164794922

# %%
# Check constraints and parameters in AMPL
# %%ampl_eval
display a, b, y, c, N, C, R, t;
# Out:
#   Cell In[121], line 3
#     display a, b, y, c, N, C, R, t;
#             ^
# SyntaxError: invalid syntax
